# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.drop('Id',inplace=True,axis=1)

# %%
data=data.sample(frac=1)
data.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 115            6.4           3.2            5.3           2.3  Iris-virginica
# 128            6.4           2.8            5.6           2.1  Iris-virginica
# 8              4.4           2.9            1.4           0.2     Iris-setosa
# 105            7.6           3.0            6.6           2.1  Iris-virginica
# 103            6.3           2.9            5.6           1.8  Iris-virginica

# %%
x=data.iloc[:,2:4].values

# %%
classes=3

# %%
center=x[np.random.choice(np.arange(len(x)),classes),:]
center
# Out:
# array([[4.5, 1.5],
#        [1.7, 0.4],
#        [1.7, 0.3]])

# %%
def show(X, C, centroids, keep = True):
    import time
    time.sleep(0.5)
    plt.cla()
    plt.plot(X[C == 0, 0], X[C == 0, 1], '*b',X[C == 1, 0], X[C == 1, 1], '*r',X[C == 2, 0], X[C == 2, 1], '*g')
    plt.plot(centroids[:,0],centroids[:,1],'*m',markersize=20)
    plt.draw()
    if keep :
        plt.ioff()
        plt.show()

# %%
iteration=10
for i in range(iteration):
    l2=[]
    new_center=[]
    for xx in x:
        l1=[]
        for yy in center:
#             print('>>>>>>>>>>>>>>>>>>>>>>>>>',yy)
            distance=np.sqrt((yy[0]-xx[0])**2+(yy[1]-xx[1])**2)
            l1.append(distance)
#             print(l1)
        l2.append(np.argmin(l1))
    l2=np.array(l2)
    for k in range(classes):
        new_center.append(x[l2 == k].mean(axis = 0))
#         print(new_center)
    center=new_center
#     print(l2)
    show(x,l2,np.array(center))

# %% [markdown]
# #### https://gist.github.com/bistaumanga/6023692
